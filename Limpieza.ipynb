# %% [markdown]
# ### 1. Análisis y pronóstico de series de tiempo
#
# - Seleccionar una base de datos con al menos una serie de tiempo univariada (se sugiere además considerar variables adicionales para generar un enfoque multivariado que se usará posteriormente).
# - Aplicar un modelo de pronóstico **lineal clásico** (por ejemplo, SARIMAX) **solo para el caso univariado**. Recuerda usar y argumentar todo el análisis que debe ser realizado para este tipo de modelos.
# - Evaluar el desempeño del modelo lineal como línea base (Usar métricas como MAPE, MSE y $R^2$).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
df = pd.read_csv("Data/AirQualityUCI.csv", sep=";")
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
# Eliminar columnas completamente vacías (las últimas dos, que aparecen Unnamed: 15)
df = df.dropna(axis=1, how='all')
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
#checar los nulos
df.isna().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(df.isna(), cmap='viridis', cbar=False, yticklabels=False)
plt.title("Ver cuantos nulos hay por variable")
plt.xlabel("Variables")
plt.ylabel("Tiempos (horas)")
plt.tight_layout()
plt.show()

# %%
# Eliminar las últimas 114 filas
df = df.iloc[:-114]
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
# Reemplazar comas por puntos en todas las columnas tipo object 
df = df.applymap(lambda x: str(x).replace(',', '.') if isinstance(x, str) else x)

# Convertir las columnas numéricas (excepto Date y Time) a float
columnas_numericas = df.columns.difference(['Date', 'Time'])
df[columnas_numericas] = df[columnas_numericas].astype(float)
# Out:
# /tmp/ipykernel_133714/3935918478.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: str(x).replace(',', '.') if isinstance(x, str) else x)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# Hay unas comas en vez de puntos, asi que hay que reemplazarlos.

# %%
#checar los nulos
df.isna().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %% [markdown]
# Podemos ver que hay en todas las variables la minima -200. Esto esta mal, ya que por ejemplo en la primera fila, son valores pequeños de entre 1 y 5, entonces nada que ver. Esto pasa en todas las variables.
#
# Calcular el porcentaje que representa respecto al total de filas. Si el porcentaje es alto, considerar imputar con más cuidado o incluso descartar esa variable del análisis.

# %%
# Contar cuántos -200 hay en cada columna
valores_menos_200 = (df == -200).sum()
print(valores_menos_200)
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
total_filas = len(df)

valores_menos_200 = (df == -200).sum()

# Calcular porcentaje
porcentaje_menos_200 = (valores_menos_200 / total_filas) * 100

resultado = pd.DataFrame({
    'Cantidad -200': valores_menos_200,
    'Porcentaje': porcentaje_menos_200
}).sort_values(by='Porcentaje', ascending=False)

print(resultado)
# Out:
#                Cantidad -200  Porcentaje
# NMHC(GT)                8443   90.231912
# CO(GT)                  1683   17.986534
# NO2(GT)                 1642   17.548360
# NOx(GT)                 1639   17.516298
# PT08.S2(NMHC)            366    3.911510
# C6H6(GT)                 366    3.911510
# PT08.S1(CO)              366    3.911510
# PT08.S5(O3)              366    3.911510
# T                        366    3.911510
# PT08.S3(NOx)             366    3.911510
# PT08.S4(NO2)             366    3.911510
# RH                       366    3.911510
# AH                       366    3.911510
# Date                       0    0.000000
# Time                       0    0.000000

# %% [markdown]
# NMHC(GT) tiene un 90.2% de valores -200, lo que la hace prácticamente inútil.
#
# NO2(GT) y NOx(GT) tienen más del 17% de datos faltantes, lo cual es bastante alto y puede afectar negativamente los modelos si no se imputa con técnicas robustas.
#
# Por estas razones mejor decidimos eliminar estas variables.

# %%
df = df.drop(columns=['NMHC(GT)', 'NO2(GT)', 'NOx(GT)'])

# %%
# Reemplazar los -200 por la moda de cada columna
for col in df.columns:
    moda = df[col][df[col] != -200].mode()[0]
    df[col] = df[col].replace(-200, moda)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     10/03/2004  18.00.00     2.6       1360.0      11.9         1046.0
# 1     10/03/2004  19.00.00     2.0       1292.0       9.4          955.0
# 2     10/03/2004  20.00.00     2.2       1402.0       9.0          939.0
# 3     10/03/2004  21.00.00     2.2       1376.0       9.2          948.0
# 4     10/03/2004  22.00.00     1.6       1272.0       6.5          836.0
# ...          ...       ...     ...          ...       ...            ...
# 9352  04/04/2005  10.00.00     3.1       1314.0      13.5         1101.0
# 9353  04/04/2005  11.00.00     2.4       1163.0      11.4         1027.0
# 9354  04/04/2005  12.00.00     2.4       1142.0      12.4         1063.0
# 9355  04/04/2005  13.00.00     2.1       1003.0       9.5          961.0
# 9356  04/04/2005  14.00.00     2.2       1071.0      11.9         1047.0
#
#       PT08.S3(NOx)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000  9357.000000    9357.000000   9357.000000
# mean      1.945410  1094.872074     9.829518     935.783478    831.484557
# std       1.388552   214.207794     7.410033     262.093035    252.527008
# min       0.100000   647.000000     0.100000     383.000000    322.000000
# 25%       1.000000   941.000000     4.000000     743.000000    666.000000
# 50%       1.500000  1053.000000     7.900000     895.000000    794.000000
# 75%       2.600000  1221.000000    13.600000    1105.000000    960.000000
# max      11.900000  2040.000000    63.700000    2214.000000   2683.000000
#
#        PT08.S4(NO2)  PT08.S5(O3)            T           RH           AH
# count   9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean    1457.505931  1015.165010    18.414919    49.385412     1.014702
# std      339.423331   392.492337     8.671004    16.991340     0.399457
# ...

# %% [markdown]
# Ahora si ya no estan esos -200 que le metian ruido a los datos.

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     10/03/2004  18.00.00     2.6       1360.0      11.9         1046.0
# 1     10/03/2004  19.00.00     2.0       1292.0       9.4          955.0
# 2     10/03/2004  20.00.00     2.2       1402.0       9.0          939.0
# 3     10/03/2004  21.00.00     2.2       1376.0       9.2          948.0
# 4     10/03/2004  22.00.00     1.6       1272.0       6.5          836.0
# ...          ...       ...     ...          ...       ...            ...
# 9352  04/04/2005  10.00.00     3.1       1314.0      13.5         1101.0
# 9353  04/04/2005  11.00.00     2.4       1163.0      11.4         1027.0
# 9354  04/04/2005  12.00.00     2.4       1142.0      12.4         1063.0
# 9355  04/04/2005  13.00.00     2.1       1003.0       9.5          961.0
# 9356  04/04/2005  14.00.00     2.2       1071.0      11.9         1047.0
#
#       PT08.S3(NOx)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...

# %% [markdown]
# Vizualización de cada variable a lo largo del tiempo

# %% [markdown]
# # CO(GT)

# %%
col = 'CO(GT)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#  CO(GT) vs Datetime. Esta variable representa la concentración de monóxido de carbono en el aire, medida en mg/m³ según la documentación del dataset.
#
# ## Patrón general:
#
# Se observan altos picos irregulares a lo largo del tiempo.
#
# Hay un cambio notable en la variabilidad: a partir de septiembre de 2004, las concentraciones de CO aumentan más frecuentemente y con mayor intensidad.
#
# ## Estacionalidad:
#
# No hay una estacionalidad clara semanal o mensual visible a simple vista, aunque puede haber patrones diarios o relacionados con la actividad humana (ej. tráfico o industria).
#
# Habría que aplicar descomposición para evaluar estacionalidad.
#
# ## Tendencia:
#
# No hay una tendencia creciente o decreciente sostenida.
#
# Sin embargo, sí hay un aparente aumento de la variabilidad en el segundo semestre de 2004.
#
#
# Hay unas partes en las que se ven lineas horizontales continuas. Algunas explicaciones son las siguientes:
# 1. Sensores defectuosos o sin lectura:
#
# Es común en datasets ambientales que cuando un sensor falla, reporte el último valor válido repetidamente.
#
# 2. Valores imputados manualmente:
#
# Si se sustituyeron datos inválidos como -200 con la moda (como hicimos antes), y esa moda se repite muchas veces seguidas, puede generar también esos bloques planos.

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
# Reemplazar puntos en la columna 'Time' por dos puntos
df['Time'] = df['Time'].str.replace('.', ':', regex=False)

# Crear la columna Datetime
df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], dayfirst=True)

# %%
# Establecer como índice y eliminar las columnas originales
df.set_index('Datetime', inplace=True)
df.drop(columns=['Date', 'Time'], inplace=True)

# %%
serie = df['CO(GT)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Es una serie con bastante variabilidad y posibles eventos extremos.
# * La tendencia es visible y muestra un ligero aumento progresivo a lo largo del tiempo, con interrupciones (que son los valores impitados con la media). Esto indica que el nivel base de CO en el aire podría estar aumentando con el tiempo (o al menos en ciertas temporadas).
# * Hay un aumento notable en la tendencia en invierno de 2004, lo cual podría coincidir con mayor uso de calefacción o condiciones atmosféricas que favorecen la concentración de CO.
# * Hay un patrón semanal repetitivo, con picos en los mismos días de cada semana
# *

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['CO(GT)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -10.374130517753361
# p-value: 2.2243547499482202e-18
# Critical Value 1%: -3.431051834977192
# Critical Value 5%: -2.8618501668189706
# Critical Value 10%: -2.5669350967161857
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# La serie ya es estacionaria entonces no es necesario hacerle ninguna diferenciación.

# %% [markdown]
# # PT08.S1(CO)

# %%
col = 'PT08.S1(CO)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# La variable PT08.S1(CO), que según la documentación del dataset de calidad del aire de la UCI.
#
# ## Patrón general:
#
# Se observan fluctuaciones fuertes en toda la serie, con picos recurrentes.
#
# Aunque los valores parecen oscilar entre 800 y 2000, hay tramos con variabilidad mucho mayor y otros más estables.
#
# ## Posible estacionalidad:
#
# Hay indicios de ciclos repetitivos, lo cual sugiere un posible patrón diario o semanal (aunque no es muy claro visualmente).
#
# Esto es consistente con el comportamiento del CO ambiental, que suele variar con la actividad humana (tráfico, industria, calefacción).
#
# ## Tendencia:
#
# No hay una tendencia sostenida a aumentar o disminuir. La serie parece moverse alrededor de una media, aunque con cambios en la varianza a lo largo del tiempo.

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
serie = df['PT08.S1(CO)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Muestra una señal densa con muchas fluctuaciones, pero sin cambios bruscos ni gaps evidentes.
# * Se observan picos de mayor intensidad en algunos tramos del segundo semestre de 2004 y principios de 2005.
# * La tendencia revela una disminución inicial hacia mediados de 2004, seguida de una recuperación leve y comportamiento más variable en el invierno.
# * Hay una estructura semanal muy clara y repetitiva, con oscilaciones amplias.

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['PT08.S1(CO)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -9.844715486330047
# p-value: 4.652553414490482e-17
# Critical Value 1%: -3.431051910310215
# Critical Value 5%: -2.8618502001074853
# Critical Value 10%: -2.566935114435797
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no se necesita diferenciar.

# %% [markdown]
# # C6H6(GT)

# %%
col = 'C6H6(GT)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## C6H6(GT): concentración real de benceno (C₆H₆) en el aire ambiente, medida en µg/m³.
#
# ## Rango y comportamiento general:
#
# Los valores de benceno varían aproximadamente entre 0 y 65 µg/m³.
#
# La serie muestra muchos picos verticales regulares, lo que sugiere fluctuaciones rápidas en la concentración.
#
# ## Patrones cíclicos o repetitivos:
#
# Se aprecian bloques donde los picos se repiten de manera algo periódica. Esto sugiere estacionalidad a nivel diario o semanal.
#
# Por ejemplo, podría haber más benceno en el aire en ciertos momentos del día, debido a tráfico o actividad industrial.
#
# ## Variabilidad temporal:
#
# La variabilidad parece aumentar hacia la mitad de la serie y después decrecer ligeramente.
#
# Esto puede estar relacionado con cambios estacionales o eventos externos
#
# ## Tendencia:
#
# No hay una tendencia sostenida (ni creciente ni decreciente) clara. La serie parece estacionaria en media, aunque con varianza fluctuante.

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
serie = df['C6H6(GT)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * La serie muestra valores entre ~0 y 50 µg/m³, con frecuentes picos que pueden reflejar actividad industrial, tráfico o condiciones meteorológicas favorables para la acumulación de benceno.
# * Mayor acumulacion en invierno del 2004.
# * Se detecta un patrón semanal fuerte y muy repetitivo, lo que sugiere que los niveles de benceno varían sistemáticamente a lo largo de cada semana.

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['PT08.S1(CO)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -9.844715486330047
# p-value: 4.652553414490482e-17
# Critical Value 1%: -3.431051910310215
# Critical Value 5%: -2.8618502001074853
# Critical Value 10%: -2.566935114435797
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no se necesita diferenciar.

# %% [markdown]
# # PT08.S3(NOx)

# %%
col = 'PT08.S3(NOx)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PT08.S3(NOx): respuesta del sensor PT08.S3 a los óxidos de nitrógeno (NOx), usando un sensor electroquímico calibrado.
#
# ## Rango y comportamiento general:
#
# Los valores están principalmente entre 500 y 2000 unidades de respuesta del sensor.
#
# Hay picos altos intermitentes, especialmente entre los índices 6000 y 8000, con un máximo cercano a 2700.
#
# ## Tendencia y estabilidad:
#
# A simple vista, no se observa una tendencia fuerte creciente o decreciente.
#
# La primera mitad muestra picos más controlados.
#
# A partir de cierto punto aprox 6000, la serie se vuelve más irregular.
#
# ## Estacionalidad:
#
# No hay un patrón cíclico claro en la gráfica completa, pero pueden existir ciclos diarios u horarios que solo se detectan en segmentos más pequeños.

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
serie = df['PT08.S3(NOx)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Se observan incrementos marcados de variabilidad hacia finales de 2004 e inicios de 2005.
# * Disminución suave durante el verano, con algunos ciclos ascendentes y descendentes hacia el invierno.
# * El patrón semanal es nítido y persistente. Hay una oscilación clara cada 7 días, lo que indica actividad cíclica en las fuentes de emisión.

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['PT08.S3(NOx)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -10.677438771947529
# p-value: 4.019998326706522e-19
# Critical Value 1%: -3.431051834977192
# Critical Value 5%: -2.8618501668189706
# Critical Value 10%: -2.5669350967161857
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no necesita diferenciación.

# %% [markdown]
# # PT08.S4(NO2)

# %%
col = 'PT08.S4(NO2)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PT08.S4(NO2): respuesta del sensor electroquímico PT08.S4, calibrado para detectar dióxido de nitrógeno (NO₂), en unidades del sensor.
#
# ## Rango y forma general:
#
# Los valores fluctúan entre aproximadamente 900 y 2700 unidades.
#
# ## Estacionalidad:
#
# Se observan ciclos frecuentes y repetitivos, especialmente en los primeros ~6000 puntos. Esto sugiere un comportamiento cíclico, posiblemente diario.
#
# Los picos tienden a ocurrir con cierta regularidad
#
# ## Variabilidad:
#
# Hay una disminución en la amplitud de los picos conforme avanza la serie. La segunda mitad muestra valores más concentrados y menos extremos.
#
# Esto podría deberse a:
#
# Cambios climáticos estacionales
#
# Cambios en la calibración del sensor.

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
serie = df['PT08.S4(NO2)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Valores entre ~800 y 2400, con oscilaciones regulares y picos bien distribuidos.
# * La tendencia muestra una disminución gradual entre agosto y noviembre, seguida por un leve aumento y luego una segunda caída.
# * Patrón semanal perfectamente definido, con altibajos regulares cada 7 días.

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['PT08.S4(NO2)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -6.346313218398851
# p-value: 2.6775771643606607e-08
# Critical Value 1%: -3.431051910310215
# Critical Value 5%: -2.8618502001074853
# Critical Value 10%: -2.566935114435797
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no se tiene que alpicar diferenciación.

# %% [markdown]
# # PT08.S5(03)

# %%
col = 'PT08.S5(O3)' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Respuesta del sensor electroquímico PT08.S5, calibrado para detectar ozono (O₃), en unidades del sensor.
#
# ## Rango y forma general:
#
# Los valores varían aproximadamente entre 300 y 2500 unidades.
#
# La serie muestra picos frecuentes e irregulares, sin una periodicidad evidente a simple vista.
#
# ## Estacionalidad:
#
# Aunque no hay una estacionalidad clara a escala completa, podrían existir patrones
#
# Esto tiene sentido, ya que el ozono a nivel del suelo suele fluctuar con radiación solar y actividad humana (más en el día, menos en la noche).
#
# ## Tendencia o cambio estructural:
#
# No hay una tendencia fuerte creciente o decreciente sostenida.
#
# Sin embargo, a partir del índice ~4000, parece haber un ligero aumento en la intensidad y frecuencia de los picos, lo cual puede ser relevante.
#
# ## Variabilidad:
#
# La variabilidad es alta en toda la serie: los valores cambian abruptamente, lo que sugiere un fenómeno sensible a múltiples factores

# %% [markdown]
# ### Descomposición con seasonal_decompose para separar tendencia, estacionalidad y residuo.

# %%
serie = df['PT08.S5(O3)']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=168) #por semana 24 x 7 

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Los valores fluctúan entre ~500 y 2300 unidades del sensor, con alta variabilidad y frecuentes picos.
# * La tendencia muestra altibajos marcados, con una subida sostenida desde mediados de 2004 y un pico claro en el invierno.
# * La estacionalidad semanal es muy clara y cíclica, con oscilaciones regulares. Esto sugiere un patrón influenciado por la actividad humana semanal

# %% [markdown]
# ### Aplicar test de estacionariedad (ADF) para confirmar si necesita diferenciación.

# %%
serie = df['PT08.S5(O3)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:serie = df['PT08.S5(O3)']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")

    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -11.04437212908431
# p-value: 5.2681839094332126e-20
# Critical Value 1%: -3.431051834977192
# Critical Value 5%: -2.8618501668189706
# Critical Value 10%: -2.5669350967161857
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no se necesita aplicar ninguna diferenciación.

# %% [markdown]
# # T (Temperatura)

# %%
col = 'T' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Temperatura del aire en grados Celsius (°C).
#
# ## Tendencia estacional clara:
#
# La serie muestra un patrón en forma de campana a lo largo del tiempo.
#
# Esto es consistente con un ciclo estacional anual, donde la temperatura sube en primavera/verano y baja en otoño/invierno.
#
# El punto más alto ocurre aproximadamente a la mitad de la serie (~verano), y los más bajos cerca del inicio y final (~invierno).
#
# ## Estacionalidad:
#
# Es evidente una estacionalidad anual.
#
# También pueden existir ciclos diarios (día/noche), pero no se aprecian claramente en la escala completa. Sería útil hacer zoom por semanas para analizarlos.

# %% [markdown]
# # Descomposición

# %%
serie = df['T']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=720) #por mes

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Muestra el comportamiento típico de una serie climática: temperaturas más altas en verano (~julio-agosto) y más bajas en invierno (~enero).
# * La tendencia confirma un comportamiento estacional anual muy claro:
#
# Sube hasta mediados de año (verano).
#
# Luego desciende de forma gradual hacia el invierno.
# * Oscilaciones rápidas que parecen representar variaciones diarias dentro de cada mes, ya que aún estamos descomponiendo a nivel horario.

# %% [markdown]
# # Test estacionalidad

# %%
serie = df['T']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -3.728217533210979
# p-value: 0.0037333086481343746
# Critical Value 1%: -3.4310513080984597
# Critical Value 5%: -2.861849933999267
# Critical Value 10%: -2.566934972785317
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no necesita diferenciación.

# %% [markdown]
# # RH (Humedad)

# %%
col = 'RH' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt# T.show()

# %% [markdown]
# Humedad relativa del aire, expresada como porcentaje (%).
#
#
# ## Rango y forma general:
#
# Los valores de humedad relativa varían entre aproximadamente 10% y 90%, lo cual es un rango normal para condiciones atmosféricas en exteriores.
#
# La serie presenta una fuerte variabilidad a corto plazo, con subidas y bajadas rápidas, lo que indica sensibilidad a cambios ambientales inmediatos.
#
# ## Estacionalidad y ciclos:
#
# Aunque no hay una forma de onda perfectamente repetitiva, hay indicios de comportamientos cíclicos amplios:
#
# Entre los puntos ~2000 y ~4000, la humedad baja de forma más sostenida.
#
# Posteriormente, entre ~5000 y ~9000, la humedad aumenta y se mantiene más alta.
#
# Esto podría reflejar transiciones estacionales, como pasar de un clima seco a uno húmedo.
#
# ## Tendencia y ruido:
#
# No se aprecia una tendencia lineal clara.
#
# La serie es muy ruidosa, lo cual es normal en datos meteorológicos como la humedad relativa, que puede cambiar rápidamente según la hora del día, la temperatura, o la precipitación.

# %% [markdown]
# # Descomposición

# %%
serie = df['RH']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=720) #por mes

# Graficar
resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Oscila entre ~20% y 80%, lo cual es típico para ambientes urbanos.
# * Hay bastante variabilidad diaria y semanal, como es común en la humedad relativa.
# * La tendencia muestra una curva estacional anual clara:
#
# Disminuye entre abril y agosto (verano seco).
#
# Aumenta hacia el otoño-invierno

# %% [markdown]
# # Test de estacionalidad

# %%
serie = df['RH']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -7.420794767979662
# p-value: 6.744920937952945e-11
# Critical Value 1%: -3.431051985659412
# Critical Value 5%: -2.8618502334031457
# Critical Value 10%: -2.5669351321592124
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no necesita diferenciación.

# %% [markdown]
# # AH

# %%
col = 'AH' 
plt.figure(figsize=(14, 4))
plt.plot(df.index, df[col], label=col)
plt.title(f'{col} vs Time')
plt.xlabel('Datetime')
plt.ylabel(col)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # AH:
# Humedad absoluta, expresada en kg/m³. Es una medida de la cantidad real de vapor de agua en el aire, independiente de la temperatura.
#
#
# ## Tendencia estacional:
#
# Al igual que la temperatura, esta serie muestra una forma de campana clara.
#
# Los valores aumentan desde el inicio (~0.6 kg/m³), alcanzan un pico en la mitad (~2.2 kg/m³), y luego disminuyen hacia el final.
#
# Esto sugiere un comportamiento estacional anual muy marcado, probablemente alineado con primavera-verano (más humedad) y otoño-invierno (menos).
#
# ## Patrones cíclicos secundarios:
#
# Dentro del gran ciclo anual, se observan fluctuaciones menores, que podrían deberse a variaciones diarias o semanales.
#
# Hay momentos con "tramos planos", lo que podría indicar valores repetidos o imputados (como en otras variables).
#
# ## Rango y comportamiento físico esperado:
#
# La humedad absoluta se mueve dentro de un rango realista (~0.4 a 2.2 kg/m³).
#
# Es importante recordar que esta medida está altamente correlacionada con la temperatura, ya que el aire caliente puede retener más vapor de agua

# %% [markdown]
# # Descomposición

# %%
serie = df['AH']

# Descomponer con modelo aditivo y frecuencia horaria
resultado = seasonal_decompose(serie, model='additive', period=720) #por mes

resultado.plot()
plt.suptitle('Descomposición estacional de CO(GT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Exhibe una curva estacional muy clara:
#
# Subida gradual hacia el verano (~julio).
#
# Pico en el tercer trimestre (~agosto-septiembre).
#
# Caída progresiva hasta el invierno (~enero).
#
# * Esto confirma que AH es ideal para detectar cambios anuales en contenido de vapor.
# * A diferencia de RH, aquí se ve una estacionalidad más limpia y estructurada, probablemente por su relación directa con la temperatura.

# %% [markdown]
# # Test de estacionalidad

# %%
serie = df['RH']

# Test de Dickey-Fuller 
resultado_adf = adfuller(serie)

print("ADF Statistic:", resultado_adf[0])
print("p-value:", resultado_adf[1])
for key, value in resultado_adf[4].items():
    print(f'Critical Value {key}: {value}')

# Interpretación simple
if resultado_adf[1] < 0.05:
    print("\nLa serie es estacionaria (se rechaza H₀).")
else:
    print("\nLa serie NO es estacionaria (no se puede rechazar H₀).")
# Out:
# ADF Statistic: -7.420794767979662
# p-value: 6.744920937952945e-11
# Critical Value 1%: -3.431051985659412
# Critical Value 5%: -2.8618502334031457
# Critical Value 10%: -2.5669351321592124
#
# La serie es estacionaria (se rechaza H₀).

# %% [markdown]
# Ya es estacionaria, no necesita diferneciación.

# %% [markdown]
# Guardar csv limpio

# %%
df.to_csv('Data/air_quality_clean.csv', index=True)
